# %% [markdown]
# # Madison RL System - Analysis Notebook
#
# This notebook provides detailed analysis of the reinforcement learning system for the Madison framework.

# %% [markdown]
# ## 1. Learning Dynamics Analysis

# %%
import sys
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from pathlib import Path

sys.path.append(str(Path().parent.parent))

from evaluation.metrics import MetricsCollector
from evaluation.visualizer import Visualizer

# %% [markdown]
# ## 2. Performance Metrics

# %%
# Load training history (example)
# This would typically load from saved training logs

# Example analysis of learning convergence
metrics_collector = MetricsCollector()

# Simulate some training data for demonstration
for episode in range(100):
    reward = 50 + 30 * (1 - np.exp(-episode / 20)) + np.random.normal(0, 5)
    metrics_collector.record_metric('episode_reward', reward, episode)

# Get convergence analysis
convergence = metrics_collector.get_convergence_analysis('episode_reward')
print("Convergence Analysis:")
print(convergence)
